# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_df=pd.read_excel('Desktop/flight_data_train.xlsx')
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_df=pd.read_excel('Desktop/flight_test_set.xlsx')
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
final_df = pd.concat([train_df, test_df])
final_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
final_df.shape
# Out:
# (5342, 10)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5342 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          5342 non-null   object
#  1   Date_of_Journey  5342 non-null   object
#  2   Source           5342 non-null   object
#  3   Destination      5342 non-null   object
#  4   Route            5342 non-null   object
#  5   Dep_Time         5342 non-null   object
#  6   Arrival_Time     5342 non-null   object
#  7   Duration         5342 non-null   object
#  8   Total_Stops      5342 non-null   object
#  9   Additional_Info  5342 non-null   object
# dtypes: object(10)
# memory usage: 459.1+ KB

# %%
final_df.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info
# 2667    14:20         16:55   2h 35m    non-stop         No info
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info
# 2669    04:00         19:15  15h 15m      1 stop         No info
# 2670    04:55         19:15  14h 20m      1 stop         No info

# %%
final_df["Date"]=final_df['Date_of_Journey'].apply(lambda x:x.split("/")[0])
final_df["Month"]=final_df['Date_of_Journey'].apply(lambda x:x.split("/")[1])
final_df["Year"]=final_df['Date_of_Journey'].apply(lambda x:x.split("/")[2])

# %%
final_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#   Date Month  Year
# 0    6    06  2019
# 1   12    05  2019
# 2   21    05  2019
# 3   21    05  2019
# 4   24    06  2019

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5342 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          5342 non-null   object
#  1   Date_of_Journey  5342 non-null   object
#  2   Source           5342 non-null   object
#  3   Destination      5342 non-null   object
#  4   Route            5342 non-null   object
#  5   Dep_Time         5342 non-null   object
#  6   Arrival_Time     5342 non-null   object
#  7   Duration         5342 non-null   object
#  8   Total_Stops      5342 non-null   object
#  9   Additional_Info  5342 non-null   object
#  10  Date             5342 non-null   object
#  11  Month            5342 non-null   object
#  12  Year             5342 non-null   object
# dtypes: object(13)
# memory usage: 584.3+ KB

# %%
final_df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
final_df.head(10)
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
# 5        Jet Airways     Delhi      Cochin  DEL → BOM → COK    18:15
# 6          Air India  Banglore   New Delhi  BLR → TRV → DEL    07:30
# 7             IndiGo   Kolkata    Banglore  CCU → HYD → BLR    15:15
# 8             IndiGo   Kolkata    Banglore        CCU → BLR    10:10
# 9        Jet Airways   Kolkata    Banglore  CCU → BOM → BLR    16:30
#
#    Arrival_Time Duration Total_Stops              Additional_Info Date Month  \
# 0  04:25 07 Jun  10h 55m      1 stop                      No info    6    06
# 1         10:20       4h      1 stop                      No info   12    05
# 2  19:00 22 May  23h 45m      1 stop  In-flight meal not included   21    05
# 3         21:00      13h      1 stop                      No info   21    05
# 4  02:45 25 Jun   2h 50m    non-stop                      No info   24    06
# 5  12:35 13 Jun  18h 20m      1 stop  In-flight meal not included   12    06
# 6         22:35   15h 5m      1 stop                      No info   12    03
# 7         20:30   5h 15m      1 stop                      No info    1    05
# 8         12:55   2h 45m    non-stop                      No info   15    03
# 9         22:35    6h 5m      1 stop                      No info   18    05
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019
# 5  2019
# 6  2019
# 7  2019
# 8  2019
# 9  2019

# %%
final_df['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0       04:25
# 1       10:20
# 2       19:00
# 3       21:00
# 4       02:45
#         ...
# 2666    20:25
# 2667    16:55
# 2668    04:25
# 2669    19:15
# 2670    19:15
# Name: Arrival_Time, Length: 5342, dtype: object

# %%
final_df['Arrival_Time']=final_df['Arrival_Time'].apply(lambda x : x.split(' ')[0])

# %%
final_df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#   Arrival_Time Duration Total_Stops              Additional_Info Date Month  \
# 0        04:25  10h 55m      1 stop                      No info    6    06
# 1        10:20       4h      1 stop                      No info   12    05
# 2        19:00  23h 45m      1 stop  In-flight meal not included   21    05
# 3        21:00      13h      1 stop                      No info   21    05
# 4        02:45   2h 50m    non-stop                      No info   24    06
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
final_df['Arrival_hour']=final_df['Arrival_Time'].str.split(':').str[0]
final_df['Arrival_min']=final_df['Arrival_Time'].str.split(':').str[1]

# %%
final_df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#   Arrival_Time Duration Total_Stops              Additional_Info Date Month  \
# 0        04:25  10h 55m      1 stop                      No info    6    06
# 1        10:20       4h      1 stop                      No info   12    05
# 2        19:00  23h 45m      1 stop  In-flight meal not included   21    05
# 3        21:00      13h      1 stop                      No info   21    05
# 4        02:45   2h 50m    non-stop                      No info   24    06
#
#    Year Arrival_hour Arrival_min
# 0  2019           04          25
# 1  2019           10          20
# 2  2019           19          00
# 3  2019           21          00
# 4  2019           02          45

# %%
final_df['Arrival_hour']=final_df['Arrival_hour'].astype(int)
final_df['Arrival_min']=final_df['Arrival_min'].astype(int)

# %%
final_df.drop('Arrival_Time',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55   2h 50m
#
#   Total_Stops              Additional_Info Date Month  Year  Arrival_hour  \
# 0      1 stop                      No info    6    06  2019             4
# 1      1 stop                      No info   12    05  2019            10
# 2      1 stop  In-flight meal not included   21    05  2019            19
# 3      1 stop                      No info   21    05  2019            21
# 4    non-stop                      No info   24    06  2019             2
#
#    Arrival_min
# 0           25
# 1           20
# 2            0
# 3            0
# 4           45

# %%
final_df['Dept_hour']=final_df['Dep_Time'].str.split(':').str[0]
final_df['Dept_min']=final_df['Dep_Time'].str.split(':').str[1]
final_df['Dept_hour']=final_df['Dept_hour'].astype(int)
final_df['Dept_min']=final_df['Dept_min'].astype(int)
final_df.drop('Dep_Time',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#              Airline    Source Destination            Route Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2h 50m
#
#   Total_Stops              Additional_Info Date Month  Year  Arrival_hour  \
# 0      1 stop                      No info    6    06  2019             4
# 1      1 stop                      No info   12    05  2019            10
# 2      1 stop  In-flight meal not included   21    05  2019            19
# 3      1 stop                      No info   21    05  2019            21
# 4    non-stop                      No info   24    06  2019             2
#
#    Arrival_min  Dept_hour  Dept_min
# 0           25         17        30
# 1           20          6        20
# 2            0         19        15
# 3            0          8         0
# 4           45         23        55

# %%
final_df['Total_Stops'].unique()
# Out:
# array(['1 stop', 'non-stop', '2 stops', '3 stops', '4 stops'],
#       dtype=object)

# %%
final_df['Total_Stops']=final_df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})

# %%
final_df.head()
# Out:
#              Airline    Source Destination            Route Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2h 50m
#
#    Total_Stops              Additional_Info Date Month  Year  Arrival_hour  \
# 0            1                      No info    6    06  2019             4
# 1            1                      No info   12    05  2019            10
# 2            1  In-flight meal not included   21    05  2019            19
# 3            1                      No info   21    05  2019            21
# 4            0                      No info   24    06  2019             2
#
#    Arrival_min  Dept_hour  Dept_min
# 0           25         17        30
# 1           20          6        20
# 2            0         19        15
# 3            0          8         0
# 4           45         23        55

# %%
final_df.drop('Route',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#              Airline    Source Destination Duration  Total_Stops  \
# 0        Jet Airways     Delhi      Cochin  10h 55m            1
# 1             IndiGo   Kolkata    Banglore       4h            1
# 2        Jet Airways     Delhi      Cochin  23h 45m            1
# 3  Multiple carriers     Delhi      Cochin      13h            1
# 4           Air Asia  Banglore       Delhi   2h 50m            0
#
#                Additional_Info Date Month  Year  Arrival_hour  Arrival_min  \
# 0                      No info    6    06  2019             4           25
# 1                      No info   12    05  2019            10           20
# 2  In-flight meal not included   21    05  2019            19            0
# 3                      No info   21    05  2019            21            0
# 4                      No info   24    06  2019             2           45
#
#    Dept_hour  Dept_min
# 0         17        30
# 1          6        20
# 2         19        15
# 3          8         0
# 4         23        55

# %%
final_df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Long layover', 'Business class',
#        'Change airports'], dtype=object)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5342 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          5342 non-null   object
#  1   Source           5342 non-null   object
#  2   Destination      5342 non-null   object
#  3   Duration         5342 non-null   object
#  4   Total_Stops      5342 non-null   int64
#  5   Additional_Info  5342 non-null   object
#  6   Date             5342 non-null   object
#  7   Month            5342 non-null   object
#  8   Year             5342 non-null   object
#  9   Arrival_hour     5342 non-null   int32
#  10  Arrival_min      5342 non-null   int32
#  11  Dept_hour        5342 non-null   int32
#  12  Dept_min         5342 non-null   int32
# dtypes: int32(4), int64(1), object(8)
# memory usage: 500.8+ KB

# %%
final_df['duration_hour']=final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
final_df.head()
# Out:
#              Airline    Source Destination Duration  Total_Stops  \
# 0        Jet Airways     Delhi      Cochin  10h 55m            1
# 1             IndiGo   Kolkata    Banglore       4h            1
# 2        Jet Airways     Delhi      Cochin  23h 45m            1
# 3  Multiple carriers     Delhi      Cochin      13h            1
# 4           Air Asia  Banglore       Delhi   2h 50m            0
#
#                Additional_Info Date Month  Year  Arrival_hour  Arrival_min  \
# 0                      No info    6    06  2019             4           25
# 1                      No info   12    05  2019            10           20
# 2  In-flight meal not included   21    05  2019            19            0
# 3                      No info   21    05  2019            21            0
# 4                      No info   24    06  2019             2           45
#
#    Dept_hour  Dept_min duration_hour
# 0         17        30            10
# 1          6        20             4
# 2         19        15            23
# 3          8         0            13
# 4         23        55             2

# %%
final_df[final_df['duration_hour']=='5m']
# Out:
#         Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 2660  Air India  Mumbai   Hyderabad       5m            2         No info
# 2660  Air India  Mumbai   Hyderabad       5m            2         No info
#
#      Date Month  Year  Arrival_hour  Arrival_min  Dept_hour  Dept_min  \
# 2660   12    03  2019            16           55         16        50
# 2660   12    03  2019            16           55         16        50
#
#      duration_hour
# 2660            5m
# 2660            5m

# %%
final_df.drop(2660,axis=0,inplace=True)

# %%
final_df['duration_hour']=final_df['duration_hour'].astype('int')

# %%
final_df['Airline'].unique()
# Out:
# array(['Jet Airways', 'IndiGo', 'Multiple carriers', 'Air Asia',
#        'Air India', 'Vistara', 'SpiceJet', 'Vistara Premium economy',
#        'GoAir', 'Multiple carriers Premium economy',
#        'Jet Airways Business'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()

final_df['Airline'] = labelencoder.fit_transform(final_df['Airline'])
final_df['Source'] = labelencoder.fit_transform(final_df['Source'])
final_df['Destination'] = labelencoder.fit_transform(final_df['Destination'])
final_df['Additional_Info'] = labelencoder.fit_transform(final_df['Additional_Info'])

# %%
final_df.head()
# Out:
#    Airline  Source  Destination Duration  Total_Stops  Additional_Info Date  \
# 0        4       2            1  10h 55m            1                5    6
# 1        3       3            0       4h            1                5   12
# 2        4       2            1  23h 45m            1                3   21
# 3        6       2            1      13h            1                5   21
# 4        0       0            2   2h 50m            0                5   24
#
#   Month  Year  Arrival_hour  Arrival_min  Dept_hour  Dept_min  duration_hour
# 0    06  2019             4           25         17        30             10
# 1    05  2019            10           20          6        20              4
# 2    05  2019            19            0         19        15             23
# 3    05  2019            21            0          8         0             13
# 4    06  2019             2           45         23        55              2
